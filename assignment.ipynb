# %%
str="Monkey D Luffy is the king of the pirates"
print(len(str))
# Out:
# 41

# %%
print(str.upper())
# Out:
# MONKEY D LUFFY IS THE KING OF THE PIRATES

# %%
print(str.lower())
# Out:
# monkey d luffy is the king of the pirates

# %%
count=0
str="Monkey D Luffy is the king of the pirates"
for i in str:
    if i in "aeiou":
     count=count+1
print(count)
# Out:
# 11

# %%
str="Monkey D Luffy is the king of the pirates"
str.split()
print(str.split())
x=len(str.split())
print(x)
# Out:
# ['Monkey', 'D', 'Luffy', 'is', 'the', 'king', 'of', 'the', 'pirates']
# 9

# %%
str="Monkey D Luffy is the king of the pirates"
y=str.replace(" ","_")
print(y)
# Out:
# Monkey_D_Luffy_is_the_king_of_the_pirates

# %%
str2="Data Science"
str2[::-1]
# Out:
# 'ecneicS ataD'

# %%
word= "madam"
if word ==word[::-1]:
    print(f"{word} is a palindrome")
else:
    print("word is not a palindrome")
# Out:
# madam is a palindrome

# %%
str="Monkey D Luffy is the king of the pirates"
z=str.replace(" ","")
print(z)
# Out:
# MonkeyDLuffyisthekingofthepirates

# %%
str="Monkey D Luffy is the king of the pirates"
y=str.startswith("Monkey")
print(y)
# Out:
# True

# %%
str="Monkey D Luffy is the king of the pirates"
str[0]
# Out:
# 'M'

# %%
str="Monkey D Luffy is the king of the pirates"
str.split()
# Out:
# ['Monkey', 'D', 'Luffy', 'is', 'the', 'king', 'of', 'the', 'pirates']

# %%
str="Monkey D Luffy is the king of the pirates"
a=str.replace("the","F")
print(a)
# Out:
# Monkey D Luffy is F king of F pirates

# %%
a="Monkey D Luffy"
b="is the king"
c=print(f"{a} and {b}")
# Out:
# Monkey D Luffy and is the king

# %%
str="Monkey D Luffy is the king of the pirates"
count=0
if "M" in str:
    count=count+1
print(count)
# Out:
# 1
