# %% [markdown]
# <a href="https://colab.research.google.com/github/Murali-Krishna22ds/December2025GenAI/blob/main/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x="data"
x.split("a")
# Out:
# ['d', 't', '']

# %%
x="data science"
x.count('a')
# Out:
# 2

# %%
x="data science"
x.replace("data","machine")
# Out:
# 'machine science'

# %%
x="data science"
x.replace("a","xxx")
# Out:
# 'dxxxtxxx science'

# %%
x="data science"
x.index("a")
# Out:
# 1

# %%
x="data science"
x[0:2]
# Out:
# 'da'

# %%
x="data science"
x[5:]
# Out:
# 'science'

# %%
x="data science"
x[5: : 2]
# Out:
# 'sine'

# %%
x="data science"
x[0:2].upper()
# Out:
# 'DA'

# %%
x="data SCIENce"
x[5:].swapcase()
x[-7:].swapcase()
# Out:
# 'scienCE'

# %%
x="data scienCE"
x.split()[1].swapcase()
# Out:
# 'SCIENce'

# %%
x="data \tscience"
x.expandtabs(8)
# Out:
# 'data    science'

# %%
x="  "
x.isspace()
# Out:
# True

# %%
x="machine learning"
x.find("e")
# Out:
# 6

# %%
x="machine learning"
x.find("e",7)
# Out:
# 9

# %%
x="machine learning"
x.find("e",3,7)
# Out:
# 6

# %%
x="machine learning"
x.find("x",3,10)
# Out:
# -1

# %%
x="data"
x.center(10,"*")
# Out:
# '***data***'

# %%
x="data"
x.zfill(20)
# Out:
# '0000000000000000data'

# %%
x=" data "
x.lstrip()
# Out:
# 'data '

# %%
x=" data "
x.rstrip()
# Out:
# ' data'

# %%
x=" data "
x.strip()
# Out:
# 'data'

# %%
x="data"

# %%
x.ljust(10)
# Out:
# 'data      '

# %%
x.rjust(10)
# Out:
# '      data'
