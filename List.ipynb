# %% [markdown]
# <a href="https://colab.research.google.com/github/Murali-Krishna22ds/December2025GenAI/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=[1,2.5,3,4+5j,"data"]
type(x)
# Out:
# list

# %%
len(x)
# Out:
# 5

# %%
type(x[0]),type(x[1]),type(x[2]),type(x[3]),type(x[4])
# Out:
# (int, float, int, complex, str)

# %%
x[0]=22
x
# Out:
# [22, 2.5, 3, (4+5j), 'data']

# %%
x=[1,2,3,[4,5,6]]
len(x)
# Out:
# 4

# %%
x[3]
# Out:
# [4, 5, 6]

# %%
x=[1,2,3,["data","science","machine"],["learning"]]
x[-2][-1][-2:]
# Out:
# 'ne'

# %%
x[4][0][-3:].upper()
# Out:
# 'ING'

# %%
Tempeature_data = [[
    #week1
    ["Monday",[24.5,34.2,22.0,36.0]],
    ["Tuesday",[25.0,33.5,23.0,35.5]],
    ["Wednesday",[23.8,32.0,21.8,34.0]]
],

 [#week2
 ["Monday",[26.1,34.0,24.2,37.2]],
 ["Tuesday",[25.8,33.5,23.7,35.1]],
 ["Wednesday",[24.9,33.3,22.5,35.7]]
  ] ]

# %%
Tempeature_data[0][-1][-1]
# Out:
# [23.8, 32.0, 21.8, 34.0]

# %%
Tempeature_data[-1][-2][-1][-1]
# Out:
# 35.1

# %%
Tempeature_data[1][1][1][-1]
# Out:
# 35.1

# %%
x=[1,2,3]
x.append([1,2,3])
x
# Out:
# [1, 2, 3, [1, 2, 3]]

# %%
x=[1,2,3]
x.extend([1,2,3])
x
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
x=[1,2,3]
x.remove(1)
x
# Out:
# [2, 3]

# %%
x=[1,2,3]
x.insert(2,"data")
x
# Out:
# [1, 2, 'data', 3]

# %%
x=[1,2,3]
x.clear()
x
# Out:
# []

# %%
x=[1,22,23.2,4]
x.sort()
x
# Out:
# [1, 4, 22, 23.2]

# %%
x=["abc","lmn","por"]
x.sort()
x
# Out:
# ['abc', 'lmn', 'por']

# %%
x.append("Zap")

# %%
x.sort()
x
# Out:
# ['Zap', 'abc', 'lmn', 'por']

# %%
x=[1,22,23.2,4]
x.sort(reverse=True)
x
# Out:
# [23.2, 22, 4, 1]

# %%
x=[1,22,23.2,4]
x.reverse()
x
# Out:
# [4, 23.2, 22, 1]

# %%
#Shallow copy
x=[1,2,3,4]
y=x
y[2]=222
print(x)
print(y)
# Out:
# [1, 2, 222, 4]
# [1, 2, 222, 4]

# %%
#Deep copy
x=[1,2,3,4]
y=x.copy()
y[2]=222
print(x)
print(y)
# Out:
# [1, 2, 3, 4]
# [1, 2, 222, 4]

# %%
x=[1,2,1,1,3,1]
x.count(1)
# Out:
# 4

# %%
x=[1,2,1,1,3,1,"a","d","a"]
x.count("a")
# Out:
# 2

# %%
x=[1,2,1,1,3,1,"a","d","a"]
x.pop(0)
# Out:
# 1

# %%
#List is mutuable
x=[1,2,3]
type(x)
x[0]=22
x
# Out:
# [22, 2, 3]

# %%
#Tuple is immutable
x=(1,2,3)
type(x)
x[0]=22
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1730745483.py in <cell line: 0>()
#       1 x=(1,2,3)
#       2 type(x)
# ----> 3 x[0]=22
#
# TypeError: 'tuple' object does not support item assignment

# %%
x=(1,2,3,4,5,1,6,1,1)
x.count(1)
# Out:
# 4

# %%
x=(1,2,3,4,5,1,6,1,1)
x.index(1)
# Out:
# 0
