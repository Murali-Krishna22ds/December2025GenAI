# %% [markdown]
# <a href="https://colab.research.google.com/github/Murali-Krishna22ds/December2025GenAI/blob/main/Datatype_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(" My name is Zoro")
# Out:
#  My name is Zoro

# %%
name="Zoro"
institute="Edukron"
age=22
is_student = False
height= 5.11
gender="Male"

# %%
type(institute)
# Out:
# str

# %%
name
# Out:
# 'Zoro'

# %%
age
# Out:
# 22

# %%
height
# Out:
# 5.11

# %%
is_student
# Out:
# False

# %%
gender
# Out:
# 'Male'

# %%
student = True

# %%
print(name)
# Out:
# Zoro

# %%
print(gender)
# Out:
# Male

# %%
student
# Out:
# True

# %%
age=25

# %%
age2=36

# %%
age2
# Out:
# 36

# %%
2student=mk (wrong)

# %%
student2=27
f_name="Roronoa"
l_name="Zoro"

# %%
@name ="mkn"(wrong)
# Out:
#   File "/tmp/ipython-input-3411810232.py", line 1
#     @name ="mkn"(wrong)
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
_name="mkn"

# %%
name="mkn"
Name="nks"
naMe="sa"

# %%
name
# Out:
# 'mkn'

# %%
Name
# Out:
# 'nks'

# %%
naMe
# Out:
# 'sa'

# %%
if=4
# Out:
#   File "/tmp/ipython-input-1173836557.py", line 1
#     if=4
#       ^
# SyntaxError: invalid syntax

# %%
#Arithemetic operators

# %%
3**2
# Out:
# 9

# %%
10%3
# Out:
# 1

# %%
10//6
# Out:
# 1

# %%
10/3
# Out:
# 3.3333333333333335

# %%
9*8
# Out:
# 72

# %%
10-3
# Out:
# 7

# %%
10+3
# Out:
# 13

# %%
print(7==18)
print(7==7)
print(7!=7)
# Out:
# False
# True
# False

# %%
x=10
y=15

# %%
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
print(x>=y)
print(x<=y)
# Out:
# False
# True
# False
# True
# False
# True

# %%
#Logical operators

# %%
(5>1 and 5<7)
# Out:
# True

# %%
(5>1 and 4>7)
# Out:
# False

# %%
(3>1 or 7<9)
# Out:
# True

# %%
(1>3 or 8<10)
# Out:
# True

# %%
(3>5 or 9<1)
# Out:
# False

# %%
(3>5 or 9>1)
# Out:
# True

# %%
not(5>10)
# Out:
# True

# %%
not(1<10)
# Out:
# False
